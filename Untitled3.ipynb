# %%
import pandas as pd
import numpy as np

# %%
data_team = pd.read_csv('teams_stats.csv', delimiter=',')

# %%
data_team.head(10)
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
# 5           5  1950.0       Ed Bartels    F  24.0  NYK   2.0 NaN NaN  NaN
# 6           6  1950.0      Ralph Beard    G  22.0  INO  60.0 NaN NaN  NaN
# 7           7  1950.0       Gene Berce  G-F  23.0  TRI   3.0 NaN NaN  NaN
# 8           8  1950.0    Charlie Black  F-C  28.0  TOT  65.0 NaN NaN  NaN
# 9           9  1950.0    Charlie Black  F-C  28.0  FTW  36.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# ...

# %%
data_team.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
data_team_new = data_team[['Year', 'Tm', 'Player', 'Age', 'Pos', 'PTS']]
data_team_new
# Out:
#          Year   Tm             Player   Age  Pos    PTS
# 0      1950.0  FTW    Curly Armstrong  31.0  G-F  458.0
# 1      1950.0  INO       Cliff Barker  29.0   SG  279.0
# 2      1950.0  CHS      Leo Barnhorst  25.0   SF  438.0
# 3      1950.0  TOT         Ed Bartels  24.0    F   63.0
# 4      1950.0  DNN         Ed Bartels  24.0    F   59.0
# ...       ...  ...                ...   ...  ...    ...
# 24686  2017.0  CHO        Cody Zeller  24.0   PF  639.0
# 24687  2017.0  BOS       Tyler Zeller  27.0    C  178.0
# 24688  2017.0  ORL  Stephen Zimmerman  20.0    C   23.0
# 24689  2017.0  CHI        Paul Zipser  22.0   SF  240.0
# 24690  2017.0  LAL        Ivica Zubac  19.0    C  284.0
#
# [24691 rows x 6 columns]

# %%
import math
data_team_new['Year'] = [int(0 if math.isnan(x) else x) for x in data_team_new['Year']]
data_team_new['Age'] = [int(0 if math.isnan(x) else x) for x in data_team_new['Age']]
data_team_new
# Out:
# <ipython-input-7-6e3e43b9dc2f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_team_new['Year'] = [int(0 if math.isnan(x) else x) for x in data_team_new['Year']]
# <ipython-input-7-6e3e43b9dc2f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_team_new['Age'] = [int(0 if math.isnan(x) else x) for x in data_team_new['Age']]
#        Year   Tm             Player  Age  Pos    PTS
# 0      1950  FTW    Curly Armstrong   31  G-F  458.0
# ...

# %%
cnt = sum([int(1 if math.isnan(x) else 0) for x in data_team['Year']])
cnt
# Out:
# 67

# %%
data_new2 = data_team.copy()
positions = ['SG', 'PG', 'SF', 'PF', 'C']
data_new2['Pos'] = [p if p in positions else 'other' for p in data_new2['Pos']]
data_new2
# Out:
#        Unnamed: 0    Year             Player    Pos   Age   Tm     G    GS  \
# 0               0  1950.0    Curly Armstrong  other  31.0  FTW  63.0   NaN
# 1               1  1950.0       Cliff Barker     SG  29.0  INO  49.0   NaN
# 2               2  1950.0      Leo Barnhorst     SF  25.0  CHS  67.0   NaN
# 3               3  1950.0         Ed Bartels  other  24.0  TOT  15.0   NaN
# 4               4  1950.0         Ed Bartels  other  24.0  DNN  13.0   NaN
# ...           ...     ...                ...    ...   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller     PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller      C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman      C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser     SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac      C  19.0  LAL  38.0  11.0
#
# ...

# %%
data_new2.groupby('Pos')['PTS'].mean().sort_values(ascending=False)
# Out:
# Pos
# SF       563.556076
# SG       562.697360
# PG       509.365103
# PF       500.177608
# C        452.378861
# other    271.978408
# Name: PTS, dtype: float64

# %%
data_new2.groupby(['Year', 'Pos']).mean().sort_values(by=['Year', 'PTS'], ascending=[True, False])
# Out:
#                 Unnamed: 0        Age          G         GS           MP  \
# Year   Pos
# 1950.0 SF       111.800000  25.800000  62.800000        NaN          NaN
#        PF       147.650000  25.150000  55.100000        NaN          NaN
#        PG       134.066667  26.866667  55.333333        NaN          NaN
#        C        163.555556  25.750000  40.305556        NaN          NaN
#        SG       193.294118  24.470588  47.352941        NaN          NaN
# ...                    ...        ...        ...        ...          ...
# 2017.0 SG     24401.600000  26.248000  48.824000  20.984000  1147.368000
#        SF     24351.223140  26.900826  50.479339  23.438017  1187.809917
#        C      24414.654867  26.265487  49.415929  24.159292  1039.946903
#        PF     24396.563025  26.075630  45.848739  20.613445   976.369748
#        other  24405.000000  25.000000  70.000000   1.000000   980.000000
#
#                     PER       TS%      3PAr       FTr       ORB%  ...  \
# ...
